# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayinipully/Coders-Week-Machine-Learning/blob/master/day2problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# !wget http://iali.in/datasets/Social_Network_Ads.csv
dataset = pd.read_csv('http://iali.in/datasets/Social_Network_Ads.csv')
dataset.sample(10)
dataset.describe()
x = dataset.iloc[:,[2,3]].values
y = dataset.iloc[:,4].values
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2)
from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)
y_pred= clf.predict(x_test)
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
classes=['0','1']
classification_report(y_test,y_pred,target_names=classes)
accuracy_score(y_pred,y_test)
df=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
df
import matplotlib.pyplot as plt
df1=df.head(400)
df1.plot(kind='bar', figsize=(20,10))
plt.grid(which='minor',linestyle='-',linewidth='1',color="green")
plt.grid(which='minor',linestyle=':',linewidth='1',color="black")
plt.show()
# Out:
# --2020-06-02 13:19:53--  http://iali.in/datasets/Social_Network_Ads.csv
# Resolving iali.in (iali.in)... 156.67.222.125
# Connecting to iali.in (iali.in)|156.67.222.125|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10926 (11K) [text/plain]
# Saving to: ‘Social_Network_Ads.csv.24’
#
# Social_Network_Ads. 100%[===================>]  10.67K  --.-KB/s    in 0s
#
# 2020-06-02 13:19:53 (188 MB/s) - ‘Social_Network_Ads.csv.24’ saved [10926/10926]
